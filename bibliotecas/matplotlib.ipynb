# %% [markdown]
# # Anotações de estudo sobre a Biblioteca MathPlotLib

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Exemplo simples

# %%
fig, ax = plt.subplots()
ax.plot([1,2,3,4],[3,1,3,4])
plt.show()

# %% [markdown]
# - no exemplo abaixo temos os principais atributos de um gráfico

# %% [markdown]
# <img src='./imgs/mathplotlib.png'>

# %% [markdown]
# #### figure

# %%
fig = plt.figure()
fig,ax = plt.subplots()
fig,axs = plt.subplots(2,2)
fig,axs = plt.subplot_mosaic([['left','right_top'],['left','right_bottom']])

# %% [markdown]
# #### Axes

# %%
np.random.seed(19680801)

data = {
    'a' : np.arange(50),
    'c' : np.random.randint(0,50,50),
    'd': np.random.randn(50)
}

data['b'] = data['a'] + 10 * np.random.randn(50)
data['d'] = np.abs(data['d']) * 100

# %%
fig,ax = plt.subplots(figsize=(5,2.7),layout='constrained')
ax.scatter('a','b',c='c',s='d',data=data)
ax.set_xlabel('entry a')
ax.set_ylabel('entry b')
# Out:
# Text(0, 0.5, 'entry b')

# %% [markdown]
# ### Estilos de Codigo

# %% [markdown]
# #### explicit

# %%
x = np.linspace(0,2,100)

fig,ax = plt.subplots(figsize=(5,2.7))

ax.plot(x,x,label='linear')
ax.plot(x,x*x,label='quandratic')
ax.plot(x,x*x*x,label='cubic')

ax.set_title('Simple Plot')
ax.set_xlabel('x label')  
ax.set_ylabel('y label') 

# ax.legend(['linear','quadratic','cubic'])
# Out:
# Text(0, 0.5, 'y label')

# %% [markdown]
# #### Pyplot-style

# %%
plt.figure(figsize=(5,2.7))
plt.plot(x,x,label='linear')
plt.plot(x,x*x,label='quadratic')
plt.plot(x,x*x*x,label='cubic')

plt.ylabel('y label')
plt.xlabel('x label')
plt.title('simple plot')
plt.legend()
# Out:
# Text(0.5, 0, 'x label')

# %% [markdown]
# #### criando funções de ajuda

# %%
def my_plotter (ax,data1,data2,param_dict):
    out = ax.plot(data1,data2,**param_dict)
    return out

# %%
data1, data2, data3, data4 = np.random.randn(4, 100)

# %%
fig,(ax1,ax2) = plt.subplots(1,2,figsize=(5,2.7))

my_plotter(ax1,data1,data2,{'marker': 'x'})
my_plotter(ax2,data3,data4,{'marker':'o'})

# %% [markdown]
# #### Estilos Artisticos

# %%
rand1 = np.random.rand(10)

fig,ax = plt.subplots(figsize=(5,2.7))

ax.plot(data2)

# %%
fig, ax = plt.subplots(figsize=(5, 2.7))
x = np.arange(len(data1))
ax.plot(x, np.cumsum(data1), color='blue', linewidth=3, linestyle='--')
l, = ax.plot(x, np.cumsum(data2), color='orange', linewidth=2)
l.set_linestyle(':')

# %%
fig, ax = plt.subplots(figsize=(5, 2.7))

t = np.arange(0.0, 5.0, 0.01)
s = np.cos(2  * np.pi * t)
line, = ax.plot(t, s, lw=2)
